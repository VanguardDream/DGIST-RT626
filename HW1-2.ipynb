# %% [markdown]
# # RT626 HW1 #2 MNIST 이미지 세트를 활용하여 CNN 구성하기
# ## Dataset 구조 조정하기
#
# 기본 데이터셋에는 60000장의 사진이 있는데 문제에서 제시한 바와 같이 Train에 5000장 Validation에 1000장 Test에 1000장을 할당하는 과정을 진행

# %%
import os
import tensorflow as tf

(x_train, y_triain),(x_test, y_test) = tf.keras.datasets.mnist.load_data(path="mnist.npz")

# %% [markdown]
# ### MNIST Dataset 분류하기

# %%
import os, shutil

exec_path = os.getcwd()
root_path = os.path.join(exec_path,'dataset\\mnist')

origin_trainset_path = os.path.join(root_path,'trainingSet')

new_trainset_path = os.path.join(root_path,'n_train')
new_validationset_path = os.path.join(root_path,'n_validation')
new_testset_path = os.path.join(root_path,'n_test')

if not(os.path.isdir(new_trainset_path)):
    os.mkdir(new_trainset_path)
if not(os.path.isdir(new_validationset_path)):
    os.mkdir(new_validationset_path)
if not(os.path.isdir(new_testset_path)):
    os.mkdir(new_testset_path)

# %% [markdown]
# ### 필요한 데이터 복사하기

# %%
if not(os.path.isdir(new_trainset_path+'\\0')):
    #폴더 생성
    if not(os.path.isdir(new_trainset_path+'\\0')):
        os.mkdir(new_trainset_path+'\\0')
    
    #Original 데이터 리스트 생성
    fnames = os.listdir(os.path.join(origin_trainset_path,'0'))
    fnames =fnames[:500]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'0'), fname)
        dst = os.path.join(os.path.join(new_trainset_path,'0'), fname)

        shutil.copy(src, dst)
    print("새로운 Train set 복사 완료 - class : 0")

if not(os.path.isdir(new_validationset_path+'\\0')):
    #폴더 생성
    if not(os.path.isdir(new_validationset_path+'\\0')):
        os.mkdir(new_validationset_path+'\\0')

    fnames = os.listdir(os.path.join(origin_trainset_path,'0'))
    fnames =fnames[500:600]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'0'), fname)
        dst = os.path.join(os.path.join(new_validationset_path,'0'), fname)

        shutil.copy(src, dst)
    print("새로운 Validation set 복사 완료 - class : 0")

if not(os.path.isdir(new_testset_path+'\\0')):
    #폴더 생성
    if not(os.path.isdir(new_testset_path+'\\0')):
        os.mkdir(new_testset_path+'\\0')

    fnames = os.listdir(os.path.join(origin_trainset_path,'0'))
    fnames =fnames[600:700]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'0'), fname)
        dst = os.path.join(os.path.join(new_testset_path,'0'), fname)

        shutil.copy(src, dst)
    print("새로운 test set 복사 완료 - class : 0")

#####

if not(os.path.isdir(new_trainset_path+'\\1')):
    #폴더 생성
    if not(os.path.isdir(new_trainset_path+'\\1')):
        os.mkdir(new_trainset_path+'\\1')
    
    #Original 데이터 리스트 생성
    fnames = os.listdir(os.path.join(origin_trainset_path,'1'))
    fnames =fnames[:500]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'1'), fname)
        dst = os.path.join(os.path.join(new_trainset_path,'1'), fname)

        shutil.copy(src, dst)
    print("새로운 Train set 복사 완료 - class : 1")

if not(os.path.isdir(new_validationset_path+'\\1')):
    #폴더 생성
    if not(os.path.isdir(new_validationset_path+'\\1')):
        os.mkdir(new_validationset_path+'\\1')

    fnames = os.listdir(os.path.join(origin_trainset_path,'1'))
    fnames =fnames[500:600]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'1'), fname)
        dst = os.path.join(os.path.join(new_validationset_path,'1'), fname)

        shutil.copy(src, dst)
    print("새로운 Validation set 복사 완료 - class : 1")

if not(os.path.isdir(new_testset_path+'\\1')):
    #폴더 생성
    if not(os.path.isdir(new_testset_path+'\\1')):
        os.mkdir(new_testset_path+'\\1')

    fnames = os.listdir(os.path.join(origin_trainset_path,'1'))
    fnames =fnames[600:700]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'1'), fname)
        dst = os.path.join(os.path.join(new_testset_path,'1'), fname)

        shutil.copy(src, dst)
    print("새로운 test set 복사 완료 - class : 1")

#####

if not(os.path.isdir(new_trainset_path+'\\2')):
    #폴더 생성
    if not(os.path.isdir(new_trainset_path+'\\2')):
        os.mkdir(new_trainset_path+'\\2')
    
    #Original 데이터 리스트 생성
    fnames = os.listdir(os.path.join(origin_trainset_path,'2'))
    fnames =fnames[:500]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'2'), fname)
        dst = os.path.join(os.path.join(new_trainset_path,'2'), fname)

        shutil.copy(src, dst)
    print("새로운 Train set 복사 완료 - class : 2")

if not(os.path.isdir(new_validationset_path+'\\2')):
    #폴더 생성
    if not(os.path.isdir(new_validationset_path+'\\2')):
        os.mkdir(new_validationset_path+'\\2')

    fnames = os.listdir(os.path.join(origin_trainset_path,'2'))
    fnames =fnames[500:600]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'2'), fname)
        dst = os.path.join(os.path.join(new_validationset_path,'2'), fname)

        shutil.copy(src, dst)
    print("새로운 Validation set 복사 완료 - class : 2")

if not(os.path.isdir(new_testset_path+'\\2')):
    #폴더 생성
    if not(os.path.isdir(new_testset_path+'\\2')):
        os.mkdir(new_testset_path+'\\2')

    fnames = os.listdir(os.path.join(origin_trainset_path,'2'))
    fnames =fnames[600:700]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'2'), fname)
        dst = os.path.join(os.path.join(new_testset_path,'2'), fname)

        shutil.copy(src, dst)
    print("새로운 test set 복사 완료 - class : 2")

#####

if not(os.path.isdir(new_trainset_path+'\\3')):
    #폴더 생성
    if not(os.path.isdir(new_trainset_path+'\\3')):
        os.mkdir(new_trainset_path+'\\3')
    
    #Original 데이터 리스트 생성
    fnames = os.listdir(os.path.join(origin_trainset_path,'3'))
    fnames =fnames[:500]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'3'), fname)
        dst = os.path.join(os.path.join(new_trainset_path,'3'), fname)

        shutil.copy(src, dst)
    print("새로운 Train set 복사 완료 - class : 3")

if not(os.path.isdir(new_validationset_path+'\\3')):
    #폴더 생성
    if not(os.path.isdir(new_validationset_path+'\\3')):
        os.mkdir(new_validationset_path+'\\3')

    fnames = os.listdir(os.path.join(origin_trainset_path,'3'))
    fnames =fnames[500:600]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'3'), fname)
        dst = os.path.join(os.path.join(new_validationset_path,'3'), fname)

        shutil.copy(src, dst)
    print("새로운 Validation set 복사 완료 - class : 3")

if not(os.path.isdir(new_testset_path+'\\3')):
    #폴더 생성
    if not(os.path.isdir(new_testset_path+'\\3')):
        os.mkdir(new_testset_path+'\\3')

    fnames = os.listdir(os.path.join(origin_trainset_path,'3'))
    fnames =fnames[600:700]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'3'), fname)
        dst = os.path.join(os.path.join(new_testset_path,'3'), fname)

        shutil.copy(src, dst)
    print("새로운 test set 복사 완료 - class : 3")

#####

if not(os.path.isdir(new_trainset_path+'\\4')):
    #폴더 생성
    if not(os.path.isdir(new_trainset_path+'\\4')):
        os.mkdir(new_trainset_path+'\\4')
    
    #Original 데이터 리스트 생성
    fnames = os.listdir(os.path.join(origin_trainset_path,'4'))
    fnames =fnames[:500]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'4'), fname)
        dst = os.path.join(os.path.join(new_trainset_path,'4'), fname)

        shutil.copy(src, dst)
    print("새로운 Train set 복사 완료 - class : 4")

if not(os.path.isdir(new_validationset_path+'\\4')):
    #폴더 생성
    if not(os.path.isdir(new_validationset_path+'\\4')):
        os.mkdir(new_validationset_path+'\\4')

    fnames = os.listdir(os.path.join(origin_trainset_path,'4'))
    fnames =fnames[500:600]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'4'), fname)
        dst = os.path.join(os.path.join(new_validationset_path,'4'), fname)

        shutil.copy(src, dst)
    print("새로운 Validation set 복사 완료 - class : 4")

if not(os.path.isdir(new_testset_path+'\\4')):
    #폴더 생성
    if not(os.path.isdir(new_testset_path+'\\4')):
        os.mkdir(new_testset_path+'\\4')

    fnames = os.listdir(os.path.join(origin_trainset_path,'4'))
    fnames =fnames[600:700]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'4'), fname)
        dst = os.path.join(os.path.join(new_testset_path,'4'), fname)

        shutil.copy(src, dst)
    print("새로운 test set 복사 완료 - class : 4")

#####

if not(os.path.isdir(new_trainset_path+'\\5')):
    #폴더 생성
    if not(os.path.isdir(new_trainset_path+'\\5')):
        os.mkdir(new_trainset_path+'\\5')
    
    #Original 데이터 리스트 생성
    fnames = os.listdir(os.path.join(origin_trainset_path,'5'))
    fnames =fnames[:500]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'5'), fname)
        dst = os.path.join(os.path.join(new_trainset_path,'5'), fname)

        shutil.copy(src, dst)
    print("새로운 Train set 복사 완료 - class : 5")

if not(os.path.isdir(new_validationset_path+'\\5')):
    #폴더 생성
    if not(os.path.isdir(new_validationset_path+'\\5')):
        os.mkdir(new_validationset_path+'\\5')

    fnames = os.listdir(os.path.join(origin_trainset_path,'5'))
    fnames =fnames[500:600]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'5'), fname)
        dst = os.path.join(os.path.join(new_validationset_path,'5'), fname)

        shutil.copy(src, dst)
    print("새로운 Validation set 복사 완료 - class : 5")

if not(os.path.isdir(new_testset_path+'\\5')):
    #폴더 생성
    if not(os.path.isdir(new_testset_path+'\\5')):
        os.mkdir(new_testset_path+'\\5')

    fnames = os.listdir(os.path.join(origin_trainset_path,'5'))
    fnames =fnames[600:700]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'5'), fname)
        dst = os.path.join(os.path.join(new_testset_path,'5'), fname)

        shutil.copy(src, dst)
    print("새로운 test set 복사 완료 - class : 5")
   
#####

if not(os.path.isdir(new_trainset_path+'\\6')):
    #폴더 생성
    if not(os.path.isdir(new_trainset_path+'\\6')):
        os.mkdir(new_trainset_path+'\\6')
    
    #Original 데이터 리스트 생성
    fnames = os.listdir(os.path.join(origin_trainset_path,'6'))
    fnames =fnames[:500]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'6'), fname)
        dst = os.path.join(os.path.join(new_trainset_path,'6'), fname)

        shutil.copy(src, dst)
    print("새로운 Train set 복사 완료 - class : 6")

if not(os.path.isdir(new_validationset_path+'\\6')):
    #폴더 생성
    if not(os.path.isdir(new_validationset_path+'\\6')):
        os.mkdir(new_validationset_path+'\\6')

    fnames = os.listdir(os.path.join(origin_trainset_path,'6'))
    fnames =fnames[500:600]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'6'), fname)
        dst = os.path.join(os.path.join(new_validationset_path,'6'), fname)

        shutil.copy(src, dst)
    print("새로운 Validation set 복사 완료 - class : 6")

if not(os.path.isdir(new_testset_path+'\\6')):
    #폴더 생성
    if not(os.path.isdir(new_testset_path+'\\6')):
        os.mkdir(new_testset_path+'\\6')

    fnames = os.listdir(os.path.join(origin_trainset_path,'6'))
    fnames =fnames[600:700]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'6'), fname)
        dst = os.path.join(os.path.join(new_testset_path,'6'), fname)

        shutil.copy(src, dst)
    print("새로운 test set 복사 완료 - class : 6")

#####

if not(os.path.isdir(new_trainset_path+'\\7')):
    #폴더 생성
    if not(os.path.isdir(new_trainset_path+'\\7')):
        os.mkdir(new_trainset_path+'\\7')
    
    #Original 데이터 리스트 생성
    fnames = os.listdir(os.path.join(origin_trainset_path,'7'))
    fnames =fnames[:500]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'7'), fname)
        dst = os.path.join(os.path.join(new_trainset_path,'7'), fname)

        shutil.copy(src, dst)
    print("새로운 Train set 복사 완료 - class : 7")

if not(os.path.isdir(new_validationset_path+'\\7')):
    #폴더 생성
    if not(os.path.isdir(new_validationset_path+'\\7')):
        os.mkdir(new_validationset_path+'\\7')

    fnames = os.listdir(os.path.join(origin_trainset_path,'7'))
    fnames =fnames[500:600]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'7'), fname)
        dst = os.path.join(os.path.join(new_validationset_path,'7'), fname)

        shutil.copy(src, dst)
    print("새로운 Validation set 복사 완료 - class : 7")

if not(os.path.isdir(new_testset_path+'\\7')):
    #폴더 생성
    if not(os.path.isdir(new_testset_path+'\\7')):
        os.mkdir(new_testset_path+'\\7')

    fnames = os.listdir(os.path.join(origin_trainset_path,'7'))
    fnames =fnames[600:700]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'7'), fname)
        dst = os.path.join(os.path.join(new_testset_path,'7'), fname)

        shutil.copy(src, dst)
    print("새로운 test set 복사 완료 - class : 7")

#####

if not(os.path.isdir(new_trainset_path+'\\8')):
    #폴더 생성
    if not(os.path.isdir(new_trainset_path+'\\8')):
        os.mkdir(new_trainset_path+'\\8')
    
    #Original 데이터 리스트 생성
    fnames = os.listdir(os.path.join(origin_trainset_path,'8'))
    fnames =fnames[:500]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'8'), fname)
        dst = os.path.join(os.path.join(new_trainset_path,'8'), fname)

        shutil.copy(src, dst)
    print("새로운 Train set 복사 완료 - class : 8")

if not(os.path.isdir(new_validationset_path+'\\8')):
    #폴더 생성
    if not(os.path.isdir(new_validationset_path+'\\8')):
        os.mkdir(new_validationset_path+'\\8')

    fnames = os.listdir(os.path.join(origin_trainset_path,'8'))
    fnames =fnames[500:600]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'8'), fname)
        dst = os.path.join(os.path.join(new_validationset_path,'8'), fname)

        shutil.copy(src, dst)
    print("새로운 Validation set 복사 완료 - class : 8")

if not(os.path.isdir(new_testset_path+'\\8')):
    #폴더 생성
    if not(os.path.isdir(new_testset_path+'\\8')):
        os.mkdir(new_testset_path+'\\8')

    fnames = os.listdir(os.path.join(origin_trainset_path,'8'))
    fnames =fnames[600:700]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'8'), fname)
        dst = os.path.join(os.path.join(new_testset_path,'8'), fname)

        shutil.copy(src, dst)
    print("새로운 test set 복사 완료 - class : 8")

#####

if not(os.path.isdir(new_trainset_path+'\\9')):
    #폴더 생성
    if not(os.path.isdir(new_trainset_path+'\\9')):
        os.mkdir(new_trainset_path+'\\9')
    
    #Original 데이터 리스트 생성
    fnames = os.listdir(os.path.join(origin_trainset_path,'9'))
    fnames =fnames[:500]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'9'), fname)
        dst = os.path.join(os.path.join(new_trainset_path,'9'), fname)

        shutil.copy(src, dst)
    print("새로운 Train set 복사 완료 - class : 9")

if not(os.path.isdir(new_validationset_path+'\\9')):
    #폴더 생성
    if not(os.path.isdir(new_validationset_path+'\\9')):
        os.mkdir(new_validationset_path+'\\9')

    fnames = os.listdir(os.path.join(origin_trainset_path,'9'))
    fnames =fnames[500:600]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'9'), fname)
        dst = os.path.join(os.path.join(new_validationset_path,'9'), fname)

        shutil.copy(src, dst)
    print("새로운 Validation set 복사 완료 - class : 9")

if not(os.path.isdir(new_testset_path+'\\9')):
    #폴더 생성
    if not(os.path.isdir(new_testset_path+'\\9')):
        os.mkdir(new_testset_path+'\\9')

    fnames = os.listdir(os.path.join(origin_trainset_path,'9'))
    fnames =fnames[600:700]

    #새로운 Directory에 저장
    for fname in fnames:
        src = os.path.join(os.path.join(origin_trainset_path,'9'), fname)
        dst = os.path.join(os.path.join(new_testset_path,'9'), fname)

        shutil.copy(src, dst)
    print("새로운 test set 복사 완료 - class : 9")
# Out:
# 새로운 Train set 복사 완료 - class : 1
# 새로운 Validation set 복사 완료 - class : 1
# 새로운 test set 복사 완료 - class : 1
# 새로운 Train set 복사 완료 - class : 2
# 새로운 Validation set 복사 완료 - class : 2
# 새로운 test set 복사 완료 - class : 2
# 새로운 Train set 복사 완료 - class : 3
# 새로운 Validation set 복사 완료 - class : 3
# 새로운 test set 복사 완료 - class : 3
# 새로운 Train set 복사 완료 - class : 4
# 새로운 Validation set 복사 완료 - class : 4
# 새로운 test set 복사 완료 - class : 4
# 새로운 Train set 복사 완료 - class : 5
# 새로운 Validation set 복사 완료 - class : 5
# 새로운 test set 복사 완료 - class : 5
# 새로운 Train set 복사 완료 - class : 6
# 새로운 Validation set 복사 완료 - class : 6
# 새로운 test set 복사 완료 - class : 6
# 새로운 Train set 복사 완료 - class : 7
# 새로운 Validation set 복사 완료 - class : 7
# 새로운 test set 복사 완료 - class : 7
# 새로운 Train set 복사 완료 - class : 8
# 새로운 Validation set 복사 완료 - class : 8
# 새로운 test set 복사 완료 - class : 8
# 새로운 Train set 복사 완료 - class : 9
# 새로운 Validation set 복사 완료 - class : 9
# 새로운 test set 복사 완료 - class : 9

# %% [markdown]
# ## 학습 모델 구축하기

# %%
from tensorflow.keras import layers
from tensorflow.keras import models

model = models.Sequential()
model.add(layers.Conv2D(32,(3,3), activation='relu', input_shape=(150,150,3)))
model.add(layers.MaxPooling2D(2,2))
model.add(layers.Conv2D(64,(3,3), activation='relu'))
model.add(layers.MaxPooling2D(2,2))
model.add(layers.Conv2D(128,(3,3), activation='relu'))
model.add(layers.MaxPooling2D(2,2))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

model.summary()

from keras import models, layers, optimizers
model.compile(loss='CategoricalCrossentropy', optimizer='adam', metrics=['acc'])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_6 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 36992)             0
# ...

# %% [markdown]
# ### Image Loader 객체 생성하기
#
# 1) Argumentation하지 않는 Loader

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator()
test_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
    new_trainset_path,
    target_size=(150, 150),
    batch_size=64,
    class_mode = 'categorical')

validation_generator = test_datagen.flow_from_directory(
    new_validationset_path,
    target_size=(150, 150),
    batch_size=64,
    class_mode = 'categorical')
# Out:
# Found 5000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %% [markdown]
# 2) Argumentation하는 Loader

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen_arg = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=10)
test_datagen_arg = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=10)

train_generator_arg = train_datagen.flow_from_directory(
    new_trainset_path,
    target_size=(150, 150),
    batch_size=256,
    class_mode = 'categorical')

validation_generator_arg = test_datagen.flow_from_directory(
    new_validationset_path,
    target_size=(150, 150),
    batch_size=256,
    class_mode = 'categorical')
# Out:
# Found 5000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %% [markdown]
# ## 모델 학습시키기
#
# 1) Non Data Argumentation

# %%
history = model.fit_generator(
    train_generator, epochs=60, 
    validation_data=validation_generator
    )

import datetime
_todaydateis = datetime.datetime.now().strftime("%y_%m_%d_%H%M")

model.save('mnist_nonargument'+ _todaydateis +'.h5')
# Out:
# c:\users\doore\onedrive - dgist.ac.kr\문서\projects\dgist-rt626\.rt626\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/60
# 20/20 [==============================] - 9s 369ms/step - loss: 140.0626 - acc: 0.2691 - val_loss: 1.1660 - val_acc: 0.6510
# Epoch 2/60
# 20/20 [==============================] - 5s 235ms/step - loss: 0.7466 - acc: 0.7891 - val_loss: 0.2599 - val_acc: 0.9160
# Epoch 3/60
# 20/20 [==============================] - 5s 223ms/step - loss: 0.1677 - acc: 0.9502 - val_loss: 0.1668 - val_acc: 0.9450
# Epoch 4/60
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0392 - acc: 0.9884 - val_loss: 0.1694 - val_acc: 0.9560
# Epoch 5/60
# ...

# %% [markdown]
# 2) Data Argumentation

# %%
history_arg = model.fit_generator(
    train_generator_arg, epochs=60, 
    validation_data=validation_generator_arg
    )

import datetime
_todaydateis = datetime.datetime.now().strftime("%y_%m_%d_%H%M")

model.save('mnist_argument'+ _todaydateis +'.h5')
# Out:
# Epoch 1/60
# 20/20 [==============================] - 5s 245ms/step - loss: 1.0169e-06 - acc: 1.0000 - val_loss: 0.1997 - val_acc: 0.9690
# Epoch 2/60
# 20/20 [==============================] - 5s 240ms/step - loss: 9.9184e-07 - acc: 1.0000 - val_loss: 0.2001 - val_acc: 0.9690
# Epoch 3/60
# 20/20 [==============================] - 5s 238ms/step - loss: 9.6793e-07 - acc: 1.0000 - val_loss: 0.2003 - val_acc: 0.9690
# Epoch 4/60
# 20/20 [==============================] - 5s 243ms/step - loss: 9.4308e-07 - acc: 1.0000 - val_loss: 0.2005 - val_acc: 0.9690
# Epoch 5/60
# 20/20 [==============================] - 6s 284ms/step - loss: 9.2077e-07 - acc: 1.0000 - val_loss: 0.2009 - val_acc: 0.9690
# Epoch 6/60
# 20/20 [==============================] - 5s 244ms/step - loss: 8.9859e-07 - acc: 1.0000 - val_loss: 0.2011 - val_acc: 0.9690
# Epoch 7/60
# 20/20 [==============================] - 5s 244ms/step - loss: 8.7797e-07 - acc: 1.0000 - val_loss: 0.2014 - val_acc: 0.9690
# Epoch 8/60
# ...

# %% [markdown]
# ## 모델 성능 Plot 하기

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)
plt.plot(epochs, acc, 'bo', label= 'Training acc')
plt.plot(epochs, val_acc, 'b', label= 'Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()
plt.plot(epochs, loss, 'bo', label= 'Training loss')
plt.plot(epochs, val_loss, 'b', label= 'Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
acc = history_arg.history['acc']
val_acc = history_arg.history['val_acc']
loss = history_arg.history['loss']
val_loss = history_arg.history['val_loss']

epochs = range(1, len(acc)+1)
plt.plot(epochs, acc, 'bo', label= 'Training acc')
plt.plot(epochs, val_acc, 'b', label= 'Validation acc')
plt.title('Training and validation accuracy (Argumented)')
plt.legend()

plt.figure()
plt.plot(epochs, loss, 'bo', label= 'Training loss')
plt.plot(epochs, val_loss, 'b', label= 'Validation loss')
plt.title('Training and validation loss (Argumented)')
plt.legend()
plt.show()

# %% [markdown]
# ## 사전 학습된 모델 활용하기 (Pre-Trained Model)
# Keras를 활용하여 손글씨 분류 모델을 Import한다.

# %%
IMG_SIZE = 32
IMG_SHAPE = (IMG_SIZE, IMG_SIZE, 3)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                                        include_top=False,
                                                        weights='imagenet')
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

prediction_layer = tf.keras.layers.Dense(10)

# %%
model_pretrained = tf.keras.Sequential([
  base_model,
  global_average_layer,
  prediction_layer
])

# %%
base_learning_rate = 0.0001

model_pretrained.compile(tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Pre Trained Model 학습하기

# %%
history_pt = model_pretrained.fit_generator(
    train_generator, epochs=60, 
    validation_data=validation_generator
    )

import datetime
_todaydateis = datetime.datetime.now().strftime("%y_%m_%d_%H%M")

model.save('pretrained'+ _todaydateis +'.h5')
# Out:
# Epoch 1/60
# 79/79 [==============================] - 20s 253ms/step - loss: 0.7457 - accuracy: 0.7684 - val_loss: 2.2013 - val_accuracy: 0.4630
# Epoch 2/60
# 79/79 [==============================] - 20s 247ms/step - loss: 0.0815 - accuracy: 0.9802 - val_loss: 1.6949 - val_accuracy: 0.5630
# Epoch 3/60
# 79/79 [==============================] - 19s 241ms/step - loss: 0.0249 - accuracy: 0.9968 - val_loss: 1.4542 - val_accuracy: 0.5940
# Epoch 4/60
# 79/79 [==============================] - 19s 239ms/step - loss: 0.0124 - accuracy: 0.9992 - val_loss: 1.2523 - val_accuracy: 0.6400
# Epoch 5/60
# 79/79 [==============================] - 19s 244ms/step - loss: 0.0055 - accuracy: 0.9998 - val_loss: 1.0724 - val_accuracy: 0.6860
# Epoch 6/60
# 79/79 [==============================] - 19s 239ms/step - loss: 0.0047 - accuracy: 0.9996 - val_loss: 0.8659 - val_accuracy: 0.7430
# Epoch 7/60
# ...

# %% [markdown]
# Pre Trained Model 성능 Plot하기

# %%
import matplotlib.pyplot as plt

acc = history_pt.history['accuracy']
val_acc = history_pt.history['val_accuracy']
loss = history_pt.history['loss']
val_loss = history_pt.history['val_loss']

epochs = range(1, len(acc)+1)
plt.plot(epochs, acc, 'bo', label= 'Training acc')
plt.plot(epochs, val_acc, 'b', label= 'Validation acc')
plt.title('Training and validation accuracy (Argumented)')
plt.legend()

plt.figure()
plt.plot(epochs, loss, 'bo', label= 'Training loss')
plt.plot(epochs, val_loss, 'b', label= 'Validation loss')
plt.title('Training and validation loss (Argumented)')
plt.legend()
plt.show()
